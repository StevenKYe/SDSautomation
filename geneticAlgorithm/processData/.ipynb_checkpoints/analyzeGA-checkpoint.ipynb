# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use(['science', 'no-latex'])
# %matplotlib inline

# %%
df = pd.read_csv(r'..\uptoDateResults.csv', names=['tg', 'tint', 'tc', 'w', 'gain', 'freq'])
df = df.loc[(df != 0).any(axis=1)]
df.head()
# Out:
#       tg  tint    tc     w      gain   freq
# 0  140.0   220  7.00   700  0.112115  12.00
# 1  160.0   590  7.78  3100  0.330746  12.71
# 2  140.0   540  7.22  4000  0.302326  12.86
# 3  160.0   580  7.44  4900  0.257574  12.85
# 4  100.0   330  7.52  1200  0.131148  12.10

# %%
rounds = np.zeros(320, 'int')
for idx, _ in enumerate(rounds):
    if idx < 200:
        rounds[idx] = 1
    else:
        rounds[idx] = 2
df['round'] = rounds

# %%
firstRound = round(df[df['round']==1].describe(),2)
secondRound = round(df[df['round']==2].describe(),2)

# %%
pd.concat([firstRound, secondRound], keys=['First round statistic', 'Second round statistic'], axis=1)
# Out:
#       First round statistic                                                  \
#                          tg    tint      tc        w    gain    freq  round
# count                200.00  200.00  200.00   200.00  200.00  200.00  200.0
# mean                 198.80  447.95    7.49  2685.50    0.19   13.04    1.0
# std                   62.35  144.85    0.29  1367.07    0.19    0.60    0.0
# min                  100.00  200.00    7.00   500.00    0.01   12.00    1.0
# 25%                  140.00  330.00    7.22  1400.00    0.05   12.51    1.0
# 50%                  200.00  445.00    7.51  2500.00    0.12   13.08    1.0
# 75%                  250.00  570.00    7.74  3900.00    0.25   13.57    1.0
# max                  300.00  700.00    8.00  5000.00    1.07   13.99    1.0
#
#       Second round statistic
#                           tg    tint      tc        w    gain    freq  round
# count                 120.00  120.00  120.00   120.00  120.00  120.00  120.0
# mean                  175.29  513.33    7.46  2808.17    0.31   13.00    2.0
# std                    54.00  108.67    0.45  1248.98    0.20    0.50    0.0
# min                   100.00  200.00    5.46   800.00    0.01   12.12    2.0
# 25%                   130.00  447.50    7.18  1775.00    0.15   12.58    2.0
# 50%                   160.00  520.00    7.53  2650.00    0.29   12.99    2.0
# 75%                   220.00  590.00    7.80  3900.00    0.44   13.33    2.0
# max                   290.00  700.00    8.66  5000.00    0.79   13.93    2.0

# %%
df['level'] = df['gain'].apply(lambda value:'low'
                               if value<=0.1 else 'level1' if value<=0.4 else 'level2' if value<=0.6 else 'level3')

# %%
low = df[df['level']=='low']
level1 = df[df['level']=='level1']
level2 = df[df['level']=='level2']
level3 = df[df['level']=='level3']

# %%
subset = df[(df['level'] == 'low')|(df['level'] == 'level2')]
subset.index = range(len(subset))
cols = ['tg', 'tint', 'tc', 'w']
subset_df = subset[cols]

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

scaled_df = ss.fit_transform(subset_df)
scaled_df = pd.DataFrame(scaled_df, columns=cols)
final_df = pd.concat([scaled_df, subset['level']], axis=1)
final_df.head()
# Out:
#          tg      tint        tc         w   level
# 0  1.217945  1.405139  1.870125 -1.734650     low
# 1 -0.906321 -1.490863 -0.092346 -0.328177     low
# 2  0.400920 -1.490863  0.678625  1.468983     low
# 3 -1.559941  1.336186  0.328183  1.390845  level2
# 4 -1.723346  0.715614  0.398272 -0.484452  level2

# %%
from pandas.plotting import parallel_coordinates
pc = parallel_coordinates(final_df, 'level')

# %%
raw = pd.concat([df[df['round']==1], df.loc[280:320, :]])
elite = df.loc[200:280, :]

# %%
fig, subplots = plt.subplots(1,1,figsize=(6,4), dpi=200)
subplots.scatter(raw['gain'], raw['freq'], label='First round')
subplots.scatter(elite['gain'], elite['freq'], label='Second round')
subplots.legend()
subplots.set_xlabel(r'Brillouin gain (m-1W-1)')
subplots.set_ylabel(r'Brillouin shift frequency (GHz)')
subplots.set_title(r'Evolution of the Brillouin gain and shift frequency')
# Out:
# Text(0.5, 1.0, 'Evolution of the Brillouin gain and shift frequency')
